# %%
import os 
os.chdir('../src/')
print("Current working directory is now: ", os.getcwd())

import pandas as pd 
import numpy as np
from pandas.io.json import json_normalize
from IPython.display import display

from data_processing.data_cleaning import *
from data_processing.spotify_user import SpotifyUser
from utils.load_confs import load_credentials

spotify_creds = load_credentials()['spotify_dev_creds']
# Out:
# Current working directory is now:  C:\Users\Caroline Wang\OneDrive\Duke\Senior Year\CS316\Project\src

# %% [markdown]
# ## Example of pulling Spotify API data using Spotipy

# %%
"""
Test of initiating a SpotifyUser object.
For Ben's developer app, use
SPOTIPY_CLIENT_ID    ='46a21c22c2b84831a61e13aabc27dc30'
SPOTIPY_CLIENT_SECRET='3211a9953f4d4facbe8fad5d6b171ea2'
SPOTIPY_REDIRECT_URI  ='http://localhost:8888'
"""
# spotify = spotipy.Spotify()
new_username = 'CarolineWang'
new_user = SpotifyUser(spotify_creds['spotify_client_id'], 
                       spotify_creds['spotify_client_secret'], 
                       'http://localhost:8889', 
                       new_username)

# %%
"""
Test prints from all methods I have written.
"""
print(new_user.info())
print(new_user.get_most_recent_tracks())
print(new_user.get_saved_tracks())
print(new_user.get_saved_albums())
print(new_user.get_followed_artists())
print(new_user.get_top_tracks())
print(new_user.get_top_artists())
# Out:
# {'display_name': 'Caroline Wang', 'external_urls': {'spotify': 'https://open.spotify.com/user/314xcqarki42gnkosjtfplluumya'}, 'followers': {'href': None, 'total': 2}, 'href': 'https://api.spotify.com/v1/users/314xcqarki42gnkosjtfplluumya', 'id': '314xcqarki42gnkosjtfplluumya', 'images': [{'height': None, 'url': 'https://platform-lookaside.fbsbx.com/platform/profilepic/?asid=437581406376376&height=300&width=300&ext=1585070744&hash=AeSh3lf3VbmvN-OG', 'width': None}], 'type': 'user', 'uri': 'spotify:user:314xcqarki42gnkosjtfplluumya'}
# {'items': [{'track': {'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6UE7nl9mha6s8z0wFQFIZ2'}, 'href': 'https://api.spotify.com/v1/artists/6UE7nl9mha6s8z0wFQFIZ2', 'id': '6UE7nl9mha6s8z0wFQFIZ2', 'name': 'Robyn', 'type': 'artist', 'uri': 'spotify:artist:6UE7nl9mha6s8z0wFQFIZ2'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/2RqrWplViWHSGLzlhmDcbt'}, 'href': 'https://api.spotify.com/v1/artists/2RqrWplViWHSGLzlhmDcbt', 'id': '2RqrWplViWHSGLzlhmDcbt', 'name': 'Yaeji', 'type': 'artist', 'uri': 'spotify:artist:2RqrWplViWHSGLzlhmDcbt'}], 'available_markets': ['CA', 'US'], 'external_urls': {'spotify': 'https://open.spotify.com/album/5mHUgXZKe4szVeCMBz9MNu'}, 'href': 'https://api.spotify.com/v1/albums/5mHUgXZKe4szVeCMBz9MNu', 'id': '5mHUgXZKe4szVeCMBz9MNu', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/463c60c9a26d6a1a6c854b14531f1a3f1454b030', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/1568f03d4e128f667461451e0d7af51149df5397', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/4ad32302b0d2cfc679d031f4df370b2529912fcb', 'width': 64}], 'name': 'Beach2k20 (Yaeji Remix)', 'release_date': '2019-09-04', 'release_date_precision': 'day', 'total_tracks': 1, 'type': 'album', 'uri': 'spotify:album:5mHUgXZKe4szVeCMBz9MNu'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6
}], 'available_markets': ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'SA', 'SE', 'SG', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'US', 'UY', 'VN', 'ZA'], 'copyrights': [{'text': '(P) 1983 Sony Music Entertainment', 'type': 'P'}], 'external_ids': {'upc': '884977674606'}, 'external_urls': {'spotify': 'https://open.spotify.com/album/6ZIPTtPuvHAuCIzMUkp4UA'}, 'genres': [], 'href': 'https://api.spotify.com/v1/albums/6ZIPTtPuvHAuCIzMUkp4UA', 'id': '6ZIPTtPuvHAuCIzMUkp4UA', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2736cbcae60f3a8f1b7ed192638', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e026cbcae60f3a8f1b7ed192638', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d000048516cbcae60f3a8f1b7ed192638', 'width': 64}], 'label': 'Sony Classical', 'name': 'Bach: Cello Suites Nos. 1-6, BWV 1007-1012', 'popularity': 35, 'release_date': '1983', 'release_date_precision': 'year', 'total_tracks': 36, 'tracks': {'href': 'https://api.spotify.com/v1/albums/6ZIPTtPuvHAuCIzMUkp4UA/tracks?offset=0&limit=50', 'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'}, 'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408', 'id': '5aIqB5nVVvmFsvSdExz408', 'name': 'Johann Sebastian Bach', 'type': 'artist', 'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Dl3HXZjG6ZOWT5cV375lk'}, 'href': 'https://api.spotify.com/v1/artists/5Dl3HXZjG6ZOWT5cV375lk', 'id': '5Dl3HXZjG6ZOWT5cV375lk', 'name': 'Yo-Yo Ma', 'type': 'artist', 'uri': 'spotify:artist:5Dl3HXZjG6ZOWT5cV375lk'}], 'available_markets': ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'SA', 'SE', 'SG', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'US', 'UY', 'VN', 'ZA'], 'disc_number': 1, 'duration_ms': 151480, 'explicit': False, 'external_urls': {'spotify': 'https://open.spotify.com/track/2zVtZkGA6kELm8UdtnyjP1'}, 'href': 'https://api.spotify.com/v1/tracks/2zVtZkGA6kELm8UdtnyjP1', 'id': '2zVtZkGA6kELm8UdtnyjP1', 'is_local': False, 'name': 'Cello Suite No. 1 in G Major, BWV 1007: I. Prélude', 'preview_url': 'https://p.scdn.co/mp3-preview/b4c714f0fcb97a6558dbbc15ece4e283ee494d63?cid=46a21c22c2b84831a61e13aabc27dc30', 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:2zVtZkGA6kELm8UdtnyjP1'}, {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'}, 'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408', 'id': '5aIqB5nVVvmFsvSdExz408', 'name': 'Johann Seba ...
# {'artists': {'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2RqrWplViWHSGLzlhmDcbt'}, 'followers': {'href': None, 'total': 195686}, 'genres': ['art pop', 'electropop', 'escape room', 'experimental house'], 'href': 'https://api.spotify.com/v1/artists/2RqrWplViWHSGLzlhmDcbt', 'id': '2RqrWplViWHSGLzlhmDcbt', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/5303e1676e4a4e9110c7f4b52f81b058069a6bb6', 'width': 640}, {'height': 320, 'url': 'https://i.scdn.co/image/52ce6b86de88f4ddc4471cdde1119bb128d3d193', 'width': 320}, {'height': 160, 'url': 'https://i.scdn.co/image/8753ae52349fd6e2fd99fbba07c000800f62463c', 'width': 160}], 'name': 'Yaeji', 'popularity': 60, 'type': 'artist', 'uri': 'spotify:artist:2RqrWplViWHSGLzlhmDcbt'}], 'next': None, 'total': 1, 'cursors': {'after': None}, 'limit': 20, 'href': 'https://api.spotify.com/v1/me/following?type=artist&limit=20'}}
# {'items': [{'album': {'album_type': 'ALBUM', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/17hR0sYHpx7VYTMRfFUOmY'}, 'href': 'https://api.spotify.com/v1/artists/17hR0sYHpx7VYTMRfFUOmY', 'id': '17hR0sYHpx7VYTMRfFUOmY', 'name': 'Maurice Ravel', 'type': 'artist', 'uri': 'spotify:artist:17hR0sYHpx7VYTMRfFUOmY'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist
 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/01b36ca0f45f2f15117022a2754287a6ca1acdcc', 'width': 640}, {'height': 320, 'url': 'https://i ...

# %% [markdown]
# ## Example of cleaning spotify data
# The functions below should ALL be run in order to fill/update the schema correctly.

# %% [markdown]
# ## New Listener

# %%
clean_listener_info(new_user)
# Out:
#     display_name                   listener_id  num_followers  \
# 0  Caroline Wang  314xcqarki42gnkosjtfplluumya              2
#
#                                   listener_image_url
# 0  https://platform-lookaside.fbsbx.com/platform/...

# %% [markdown]
# ## CREATED BY,  Artists to Add (from Top Tracks)

# %%
top_track_created_by, top_track_artists_to_add = clean_top_tracks_artist_info(new_user)

display(top_track_artists_to_add.head())
display(top_track_created_by.head())
# TODO: GET THE REST OF ARTIST INFORMATION
# Out:
#                 artist_id                artist_name
# 0  17hR0sYHpx7VYTMRfFUOmY              Maurice Ravel
# 1  6Sqhwn4JweupJ3sn9zHNsq            Amandine Savary
# 2  3qprTw1SHzbubNcJPqFaFS             Vineta Sareika
# 3  5nRDtK82lHmYRXnKjAzI9j  Christian-Pierre La Marca
# 4  6UE7nl9mha6s8z0wFQFIZ2                      Robyn
#                 artist_id                track_id
# 0  17hR0sYHpx7VYTMRfFUOmY  0xH4hjpQfNInY3lqC3Osc1
# 1  6Sqhwn4JweupJ3sn9zHNsq  0xH4hjpQfNInY3lqC3Osc1
# 2  3qprTw1SHzbubNcJPqFaFS  0xH4hjpQfNInY3lqC3Osc1
# 3  5nRDtK82lHmYRXnKjAzI9j  0xH4hjpQfNInY3lqC3Osc1
# 4  6UE7nl9mha6s8z0wFQFIZ2  1RI3rY6Y5Shrr2pFCO1xmu

# %% [markdown]
# ## Top Tracks table, AlbumContainsTrack table

# %%
top_tracks, album_contains_track, top_tracks_albums_to_add = clean_top_tracks_album_info(new_user)

# %%
display(top_tracks.head())
display(album_contains_track.head())
display(top_tracks_albums_to_add.head())
# Out:
#                  track_id                                         track_name  \
# 0  0xH4hjpQfNInY3lqC3Osc1  Trio pour piano violon & violoncelle: II. Pant...
# 1  1RI3rY6Y5Shrr2pFCO1xmu                            Beach2k20 - Yaeji Remix
# 2  2Fxmhks0bxGSBdJ92vM42m                                            bad guy
# 3  39nTNk5MfyiiRupTwn1iyC                                  Take It Out On Me
# 4  7BlBVFwvbWvcwNcUarQmjk                                    Yo x Ti Tu x Mi
#
#    track_pop                                        preview_url   time_span
# 0         10  https://p.scdn.co/mp3-preview/c822c5e60fdc9cf4...  short_term
# 1         36  https://p.scdn.co/mp3-preview/08be7225f817da6f...  short_term
# 2         94  https://p.scdn.co/mp3-preview/11fadb5f777b56f8...  short_term
# 3         77  https://p.scdn.co/mp3-preview/3acbfa9184485bd6...  short_term
# 4         85  https://p.scdn.co/mp3-preview/f8d270e551ebd663...  short_term
#                  album_id                track_id
# 0  3FhRqpxS0Rlx0f4RtZMaBh  0xH4hjpQfNInY3lqC3Osc1
# 1  5mHUgXZKe4szVeCMBz9MNu  1RI3rY6Y5Shrr2pFCO1xmu
# 2  0S0KGZnfBGSIssfF54WSJh  2Fxmhks0bxGSBdJ92vM42m
# 3  63iWSELt9V1kV6RSMxN7Ii  39nTNk5MfyiiRupTwn1iyC
# 4  3844bY26oeSkqd06th4EYp  7BlBVFwvbWvcwNcUarQmjk
#   album_type                album_id  \
# 0      ALBUM  3FhRqpxS0Rlx0f4RtZMaBh
# 1     SINGLE  5mHUgXZKe4szVeCMBz9MNu
# 2      ALBUM  0S0KGZnfBGSIssfF54WSJh
# 3      ALBUM  63iWSELt9V1kV6RSMxN7Ii
# 4     SINGLE  3844bY26oeSkqd06th4EYp
#
#                                           album_name  \
# 0  Ravel: Trio Sonate pour violon et violoncelle ...
# 1                            Beach2k20 (Yaeji Remix)
# 2            WHEN WE ALL FALL ASLEEP WHERE DO WE GO?
# 3                                            Changes
# 4                                    Yo x Ti Tu x Mi
#
#                                      album_image_url
# 0  https://i.scdn.co/image/ab67616d0000b27309302d...
# 1  https://i.scdn.co/image/463c60c9a26d6a1a6c854b...
# 2  https://i.scdn.co/image/cd89c09ece48d687d4b6a8...
# 3  https://i.scdn.co/image/ab67616d0000b2737fe4a8...
# 4  https://i.scdn.co/image/ab67616d0000b273694844...

# %% [markdown]
# ## Albums to Add table

# %% [markdown]
# ## Top artists table, artists to add table

# %%
top_artists, top_artists_to_add = clean_top_artists_info(new_user)

display(top_artists.head())
display(top_artists_to_add.head())
# Out:
# C:\Users\Caroline Wang\OneDrive\Duke\Senior Year\CS316\Project\src\data_processing\data_cleaning.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_artists['listener_id'] = listener_info['id'][0]
# C:\Users\Caroline Wang\OneDrive\Duke\Senior Year\CS316\Project\src\data_processing\data_cleaning.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_artists['time_span'] = time_range
#                 artist_id                   listener_id   time_span
# 0  2RqrWplViWHSGLzlhmDcbt  314xcqarki42gnkosjtfplluumya  short_term
# 1  1uNFoZAHBGtllmzznpCI3s  314xcqarki42gnkosjtfplluumya  short_term
# 2  6Sqhwn4JweupJ3sn9zHNsq  314xcqarki42gnkosjtfplluumya  short_term
# 3  7ltDVBr6mKbRvohxheJ9h1  314xcqarki42gnkosjtfplluumya  short_term
# 4  0BOKp33vfgc7PUaNem18gT  314xcqarki42gnkosjtfplluumya  short_term
#                 artist_id      artist_name  artist_pop  num_followers  \
# 0  2RqrWplViWHSGLzlhmDcbt            Yaeji          60         195686
# 1  1uNFoZAHBGtllmzznpCI3s    Justin Bieber          99       33153455
# 2  6Sqhwn4JweupJ3sn9zHNsq  Amandine Savary          23            136
# 3  7ltDVBr6mKbRvohxheJ9h1          ROSALÍA          86        2723877
# 4  0BOKp33vfgc7PUaNem18gT  Ralph Kirshbaum          47          22944
#
#                                     artist_image_url
# 0  https://i.scdn.co/image/5303e1676e4a4e9110c7f4...
# 1  https://i.scdn.co/image/d745628f6659a715f0f69e...
# 2  https://i.scdn.co/image/ab67616d0000b273d2264b...
# 3  https://i.scdn.co/image/b25d176a49dfda9d754d87...
# 4  https://i.scdn.co/image/6a138dc9740f9cdd973826...
